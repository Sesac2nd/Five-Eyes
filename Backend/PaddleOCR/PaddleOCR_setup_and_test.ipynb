# %% [markdown]
# # Install PaddleOCR

# %%
# !pip install paddlepaddle

# PaddleOCR should be installed after installing PaddleX(paddlepaddle)
# !pip install paddleocr
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-3.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.5 kB)
# Collecting httpx (from paddlepaddle)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting numpy>=1.21 (from paddlepaddle)
#   Using cached numpy-2.3.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting protobuf>=3.20.2 (from paddlepaddle)
#   Using cached protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting Pillow (from paddlepaddle)
#   Using cached pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: decorator in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from paddlepaddle) (5.2.1)
# Collecting opt-einsum==3.3.0 (from paddlepaddle)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting networkx (from paddlepaddle)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: typing-extensions in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from paddlepaddle) (4.14.1)
# Collecting anyio (from httpx->paddlepaddle)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi (from httpx->paddlepaddle)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpcore==1.* (from httpx->paddlepaddle)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx->paddlepaddle)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx->paddlepaddle)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting sniffio>=1.1 (from anyio->httpx->paddlepaddle)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading paddlepaddle-3.1.0-cp311-cp311-macosx_11_0_arm64.whl (95.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 MB 36.1 MB/s  0:00:02m0:00:0100:01
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading numpy-2.3.2-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 53.1 MB/s  0:00:00
# Using cached protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.6 MB/s  0:00:00
# Downloading pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 11.9 MB/s  0:00:00eta 0:00:01
# Installing collected packages: sniffio, protobuf, Pillow, numpy, networkx, idna, h11, certifi, opt-einsum, httpcore, anyio, httpx, paddlepaddle
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [paddlepaddle] [paddlepaddle]
# Successfully installed Pillow-11.3.0 anyio-4.9.0 certifi-2025.8.3 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 networkx-3.5 numpy-2.3.2 opt-einsum-3.3.0 paddlepaddle-3.1.0 protobuf-6.31.1 sniffio-1.3.1
# Collecting paddleocr
#   Using cached paddleocr-3.1.0-py3-none-any.whl.metadata (22 kB)
# Collecting paddlex>=3.1.0 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached paddlex-3.1.3-py3-none-any.whl.metadata (78 kB)
# Collecting PyYAML>=6 (from paddleocr)
#   Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from paddleocr) (4.14.1)
# Collecting chardet (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting colorlog (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting filelock (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface_hub (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.24 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.3.2)
# Requirement already satisfied: packaging in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (25.0)
# Collecting pandas>=1.3 (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached pandas-2.3.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (91 kB)
# Requirement already satisfied: pillow in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (11.3.0)
# Collecting prettytable (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached prettytable-3.16.0-py3-none-any.whl.metadata (33 kB)
# Collecting py-cpuinfo (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting pydantic>=2 (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting requests (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting ruamel.yaml (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Collecting ujson (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached ujson-5.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.3 kB)
# Collecting einops (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting ftfy (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting GPUtil>=1.4 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached GPUtil-1.4.0.tar.gz (5.5 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Jinja2 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting opencv-contrib-python==4.10.0.84 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting pypdfium2>=4 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl.metadata (48 kB)
# Collecting regex (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached regex-2025.7.34-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tiktoken (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached tiktoken-0.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting imagesize (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain>=0.2 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-community>=0.2 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-core (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached langchain_core-0.3.72-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-openai>=0.1 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached langchain_openai-0.3.28-py3-none-any.whl.metadata (2.3 kB)
# Collecting lxml (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached lxml-6.0.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (6.6 kB)
# Collecting openai>=1.63 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached openai-1.98.0-py3-none-any.whl.metadata (29 kB)
# Collecting openpyxl (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting premailer (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached premailer-3.10.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting pyclipper (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached pyclipper-1.3.0.post6-cp311-cp311-macosx_10_9_universal2.whl.metadata (9.0 kB)
# Collecting scikit-learn (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached scikit_learn-1.7.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting shapely (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached shapely-2.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting tokenizers>=0.19 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting beautifulsoup4 (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached langchain_text_splitters-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached langsmith-0.4.10-py3-none-any.whl.metadata (14 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached sqlalchemy-2.0.42-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached charset_normalizer-3.4.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2025.8.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached aiohttp-3.12.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached frozenlist-1.7.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached multidict-6.6.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached propcache-0.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached yarl-1.20.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (73 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (4.9.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached jiter-0.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.3.1)
# Collecting tqdm>4 (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: httpcore==1.* in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.16.0)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached orjson-3.11.1-cp311-cp311-macosx_15_0_arm64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.17.0)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl.metadata (879 bytes)
# Collecting soupsieve>1.2 (from beautifulsoup4->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: wcwidth in /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages (from ftfy->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.2.13)
# Collecting MarkupSafe>=2.0 (from Jinja2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting et-xmlfile (from openpyxl->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting cssselect (from premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cssutils (from premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached cssutils-2.11.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting cachetools (from premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached cachetools-6.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting more-itertools (from cssutils->premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached more_itertools-10.7.0-py3-none-any.whl.metadata (37 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached ruamel.yaml.clib-0.2.12-cp311-cp311-macosx_13_0_arm64.whl.metadata (2.7 kB)
# Collecting scipy>=1.8.0 (from scikit-learn->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached scipy-1.16.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached paddleocr-3.1.0-py3-none-any.whl (70 kB)
# Using cached paddlex-3.1.3-py3-none-any.whl (1.7 MB)
# Downloading PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl (172 kB)
# Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (63.7 MB)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.72-py3-none-any.whl (442 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.9-py3-none-any.whl (33 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 45.4 MB/s  0:00:00
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp311-cp311-macosx_10_9_universal2.whl (198 kB)
# Downloading sqlalchemy-2.0.42-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.2 MB/s  0:00:00 eta 0:00:01
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
# Downloading aiohttp-3.12.15-cp311-cp311-macosx_11_0_arm64.whl (471 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.6.3-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.20.1-cp311-cp311-macosx_11_0_arm64.whl (89 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.7.0-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
# Using cached langchain_openai-0.3.28-py3-none-any.whl (70 kB)
# Using cached openai-1.98.0-py3-none-any.whl (767 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.10.0-cp311-cp311-macosx_11_0_arm64.whl (321 kB)
# Downloading tiktoken-0.9.0-cp311-cp311-macosx_11_0_arm64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.3 MB/s  0:00:00
# Using cached langsmith-0.4.10-py3-none-any.whl (372 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading orjson-3.11.1-cp311-cp311-macosx_15_0_arm64.whl (129 kB)
# Downloading pandas-2.3.1-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 46.6 MB/s  0:00:00eta 0:00:01
# Downloading propcache-0.3.2-cp311-cp311-macosx_11_0_arm64.whl (43 kB)
# Using cached pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl (2.7 MB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading regex-2025.7.34-cp311-cp311-macosx_11_0_arm64.whl (285 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Using cached huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
# Using cached hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
# Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl (633 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.7/633.7 kB 26.9 MB/s  0:00:00
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached colorlog-6.9.0-py3-none-any.whl (11 kB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached ftfy-6.3.1-py3-none-any.whl (44 kB)
# Using cached imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Downloading lxml-6.0.0-cp311-cp311-macosx_10_9_universal2.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 37.6 MB/s  0:00:00 eta 0:00:01
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Using cached cachetools-6.1.0-py3-none-any.whl (11 kB)
# Using cached cssselect-1.3.0-py3-none-any.whl (18 kB)
# Using cached cssutils-2.11.1-py3-none-any.whl (385 kB)
# Using cached more_itertools-10.7.0-py3-none-any.whl (65 kB)
# Using cached prettytable-3.16.0-py3-none-any.whl (33 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading pyclipper-1.3.0.post6-cp311-cp311-macosx_10_9_universal2.whl (270 kB)
# Using cached ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-macosx_13_0_arm64.whl (132 kB)
# Downloading scikit_learn-1.7.1-cp311-cp311-macosx_12_0_arm64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 59.7 MB/s  0:00:00
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.16.1-cp311-cp311-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 59.8 MB/s  0:00:00 eta 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading shapely-2.1.1-cp311-cp311-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.6 MB/s  0:00:00
# Downloading ujson-5.10.0-cp311-cp311-macosx_11_0_arm64.whl (51 kB)
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (pyproject.toml) ... done
#   Created wheel for GPUtil: filename=gputil-1.4.0-py3-none-any.whl size=7436 sha256=7224ef9b54fbb56cb0d7c0aa2d6f3019292059d29e88820c80460ed6c089bc22
#   Stored in directory: /Users/user/Library/Caches/pip/wheels/2b/4d/8f/55fb4f7b9b591891e8d3f72977c4ec6c7763b39c19f0861595
# Successfully built GPUtil
# Installing collected packages: pytz, pyclipper, py-cpuinfo, GPUtil, zstandard, urllib3, ujson, tzdata, typing-inspection, tqdm, threadpoolctl, tenacity, SQLAlchemy, soupsieve, shapely, scipy, ruamel.yaml.clib, regex, PyYAML, python-dotenv, pypdfium2, pydantic-core, propcache, prettytable, orjson, opencv-contrib-python, mypy-extensions, multidict, more-itertools, marshmallow, MarkupSafe, lxml, jsonpointer, joblib, jiter, imagesize, httpx-sse, hf-xet, ftfy, fsspec, frozenlist, filelock, et-xmlfile, einops, distro, cssselect, colorlog, charset_normalizer, chardet, cachetools, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspect, scikit-learn, ruamel.yaml, requests, pydantic, pandas, openpyxl, jsonpatch, Jinja2, cssutils, beautifulsoup4, aiosignal, tiktoken, requests-toolbelt, pydantic-settings, premailer, openai, huggingface_hub, dataclasses-json, aiohttp, tokenizers, paddlex, langsmith, langchain-core, langchain-text-splitters, langchain-openai, langchain, langchain-community, paddleocr
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83/83 [paddleocr]angchain-community]ore]]ython]
# Successfully installed GPUtil-1.4.0 Jinja2-3.1.6 MarkupSafe-3.0.2 PyYAML-6.0.2 SQLAlchemy-2.0.42 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 annotated-types-0.7.0 attrs-25.3.0 beautifulsoup4-4.13.4 cachetools-6.1.0 chardet-5.2.0 charset_normalizer-3.4.2 colorlog-6.9.0 cssselect-1.3.0 cssutils-2.11.1 dataclasses-json-0.6.7 distro-1.9.0 einops-0.8.1 et-xmlfile-2.0.0 filelock-3.18.0 frozenlist-1.7.0 fsspec-2025.7.0 ftfy-6.3.1 hf-xet-1.1.5 httpx-sse-0.4.1 huggingface_hub-0.34.3 imagesize-1.4.1 jiter-0.10.0 joblib-1.5.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-community-0.3.27 langchain-core-0.3.72 langchain-openai-0.3.28 langchain-text-splitters-0.3.9 langsmith-0.4.10 lxml-6.0.0 marshmallow-3.26.1 more-itertools-10.7.0 multidict-6.6.3 mypy-extensions-1.1.0 openai-1.98.0 opencv-contrib-python-4.10.0.84 openpyxl-3.1.5 orjson-3.11.1 paddleocr-3.1.0 paddlex-3.1.3 pandas-2.3.1 premailer-3.10.0 prettytable-3.16.0 propcache-0.3.2 py-cpuinfo-9.0.0 pyclipper-1.3.0.post6 pydantic-2.11.7 pydantic-core-2.33.2 pydantic-settings-2.10.1 pypdfium2-4.30.0 python-dotenv-1.1.1 pytz-2025.2 regex-2025.7.34 requests-2.32.4 requests-toolbelt-1.0.0 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 scikit-learn-1.7.1 scipy-1.16.1 shapely-2.1.1 soupsieve-2.7 tenacity-9.1.2 threadpoolctl-3.6.0 tiktoken-0.9.0 tokenizers-0.21.4 tqdm-4.67.1 typing-inspect-0.9.0 typing-inspection-0.4.1 tzdata-2025.2 ujson-5.10.0 urllib3-2.5.0 yarl-1.20.1 zstandard-0.23.0

# %%
# Try installing HPI(High Performance Inference)
# !paddlex --install hpi-cpu
# Out:
# Looking in links: /Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/hpip_links.html
# ERROR: Could not find a version that satisfies the requirement ultra-infer-python (from versions: none)
# ERROR: No matching distribution found for ultra-infer-python
# Traceback (most recent call last):
#   File "/Users/user/Projects/Five-Eyes/history/bin/paddlex", line 7, in <module>
#     sys.exit(console_entry())
#              ^^^^^^^^^^^^^^^
#   File "/Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/__main__.py", line 26, in console_entry
#     main()
#   File "/Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/paddlex_cli.py", line 441, in main
#     install(args)
#   File "/Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/paddlex_cli.py", line 301, in install
#     _install_hpi_deps(device_type=device_type)
#   File "/Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/paddlex_cli.py", line 261, in _install_hpi_deps
#     install_packages([package], pip_install_opts=["--find-links", str(f)])
#   File "/Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/utils/install.py", line 69, in install_packages
#     return install_packages_from_requirements_file(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/utils/install.py", line 58, in install_packages_from_requirements_file
#     return subprocess.check_call(args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py", line 413, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command '['/Users/user/Projects/Five-Eyes/history/bin/python3.11', '-m', 'pip', 'install', '-c', '/var/folders/w8/9nx854954vg2flm9j6b9mlxh0000gn/T/tmpz46ai_u4.txt', '--find-links', '/Users/user/Projects/Five-Eyes/history/lib/python3.11/site-packages/paddlex/hpip_links.html', '-r', '/var/folders/w8/9nx854954vg2flm9j6b9mlxh0000gn/T/tmpps0fup0i.txt']' returned non-zero exit status 1.

# %% [markdown]
# # Install REQUIRED Packages Done
#
# # Next, Run OCR for test

# %%
# Initialize PaddleOCR instance
import paddle
from paddleocr import PaddleOCR
paddle.set_flags({
    # CPU 메모리 사용률을 50%로 제한합니다. (0.0 ~ 1.0 사이 값)
    "FLAGS_fraction_of_cpu_memory_to_use": 0.5, 
    # 텐서 메모리 즉시 회수를 활성화하여 메모리 누수를 방지합니다.
    "FLAGS_eager_delete_tensor_gb": 0.0,
    "FLAGS_fast_eager_deletion_mode": True,
    "FLAGS_use_mkldnn": False,
})
try:
    # Try OCR with High-performance(hpi)
    ocr = PaddleOCR(
        lang='chinese_cht',
        text_det_limit_side_len = 1500,
        text_det_limit_type='max',
        cpu_threads = 1,
        use_doc_orientation_classify=True,
        use_doc_unwarping=False,
        use_textline_orientation=False,
        enable_mkldnn=False,
        ocr_version='PP-OCRv5',
        enable_hpi=True,
        )
except RuntimeError as E:
    # if failed, go with hpi disabled
    ocr = PaddleOCR(
        lang='chinese_cht',
        text_det_limit_side_len = 1500,
        text_det_limit_type='max',
        cpu_threads = 1,
        use_doc_orientation_classify=True,
        use_doc_unwarping=False,
        use_textline_orientation=False,
        enable_mkldnn=False,
        ocr_version='PP-OCRv5',
        enable_hpi=False,
        text_det_unclip_ratio=2.0,
        )
    
# Run OCR inference on a sample image 
result = ocr.predict(
    input="./cropped_images/태조실록_001권_총서_001a면_cropped_bin.png")

# Visualize the results and save the JSON results
for res in result:
    res.print()
    res.save_to_img("output")
    res.save_to_json("output")
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /Users/user/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 5278.07it/s]
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /Users/user/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 4583.94it/s]
# Creating model: ('PP-OCRv5_server_det', None)
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in /Users/user/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 5231.98it/s]
# Creating model: ('PP-OCRv5_server_rec', None)
# Using official model (PP-OCRv5_server_rec), the model files will be automatically downloaded and saved in /Users/user/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 98304.00it/s]
# {'res': {'input_path': './cropped_images/태조실록_001권_총서_001a면_cropped_bin.png', 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': False}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': False}, 'angle': 0}, 'dt_polys': array([[[  20,    0],
#         ...,
#         [  15,   34]],
#
#        ...,
#
#        [[  34, 2858],
#         ...,
#         [  34, 2931]]], shape=(23, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 1500, 'limit_type': 'max', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 2.0}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(23,)), 'text_rec_score_thresh': 0.0, 'rec_texts': ['', '餘勇略過人山城别监入館因官妓事與州官有隙州官與按', '諱克謙之女生將軍諱陽茂將軍娶上将軍李公諱康濟之女', '景英生諱忠敏忠敏生諱華生諱珍有珍有生諱宫進官進', '兢休生諱廉順廉順生諱承朔承朔生諱充慶充慶生諱景英', '生諱安社是為', '生大将軍諱勇夫大将軍生内侍执奏諱降執奏娶侍中文公', '孫軍尹金殷義之女生侍中諱自延侍中生僕射諱天祥僕射', '兵侵諸郡', '從而徙者百七十餘家嘗造船十五隻以備倭既元也窟大王', '廉議上聞兵圖之', '生阿干諱光禧阿干生司徒三重大匡諱立全司徒生諱兢休', '成桂號松軒全州大姓也有司空諱翰仕新羅娶太宗王十世', '太祖康獻至仁啓運聖文神武大王姓李氏諱旦字君晋古諱', '按廉使又将至', '太祖康獻大王實錄卷第一', '穆祖保頭陀山城以避配通前日山城别监新除', '穆祖性豪放有志四方初在全州時年二十', '穆祖恐祸及挈家浮海至東北面宜州', '', '穆祖聞之遂徙居江陵道三陟縣民願', '即德', '原'], 'rec_scores': array([0.        , ..., 0.99729437], shape=(23,)), 'rec_polys': array([[[  20,    0],
#         ...,
#         [  15,   34]],
#
#        ...,
#
#        [[  34, 2858],
#         ...,
#         [  34, 2931]]], shape=(23, 4, 2), dtype=int16), 'rec_boxes': array([[  15, ...,   46],
#        ...,
#        [  34, ..., 2931]], shape=(23, 4), dtype=int16)}}

# %% [markdown]
# # Check result

# %%
import json
from IPython.display import display, Image, JSON
def show_ocr_result(img_path, ocr_json):
    display(Image(filename=img_path, width = 1000))
    display(JSON(ocr_json))

# %%
img_path = "./output/태조실록_001권_총서_001a면_cropped_bin_ocr_res_img.png"
with open("./output/태조실록_001권_총서_001a면_cropped_bin_res.json", "r", encoding="utf-8") as f:
    ocr_json = json.load(f)

show_ocr_result(img_path, ocr_json)
